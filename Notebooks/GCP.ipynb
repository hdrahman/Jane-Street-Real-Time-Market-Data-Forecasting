# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load the dataset (relative path from the notebook's location in Exploration folder)
train_data = pd.read_parquet('../Data/train.parquet')

# Display the first few rows
train_data.head()
# Out:
#    date_id  time_id  symbol_id    weight  feature_00  feature_01  feature_02  \
# 0        0        0          1  3.889038         NaN         NaN         NaN
# 1        0        0          7  1.370613         NaN         NaN         NaN
# 2        0        0          9  2.285698         NaN         NaN         NaN
# 3        0        0         10  0.690606         NaN         NaN         NaN
# 4        0        0         14  0.440570         NaN         NaN         NaN
#
#    feature_03  feature_04  feature_05  ...  responder_0  responder_1  \
# 0         NaN         NaN    0.851033  ...     0.738489    -0.069556
# 1         NaN         NaN    0.676961  ...     2.965889     1.190077
# 2         NaN         NaN    1.056285  ...    -0.864488    -0.280303
# 3         NaN         NaN    1.139366  ...     0.408499     0.223992
# 4         NaN         NaN    0.955200  ...    -0.373387    -0.502764
#
#    responder_2  responder_3  responder_4  responder_5  responder_6  \
# 0     1.380875     2.005353     0.186018     1.218368     0.775981
# 1    -0.523998     3.849921     2.626981     5.000000     0.703665
# 2    -0.326697     0.375781     1.271291     0.099793     2.109352
# 3     2.294888     1.097444     1.225872     1.225376     1.114137
# 4    -0.348021    -3.928148    -1.591366    -5.000000    -3.572820
#
#    responder_7  responder_8  partition_id
# 0     0.346999     0.095504             0
# 1     0.216683     0.778639             0
# 2     0.670881     0.772828             0
# 3     0.775199    -1.379516             0
# 4    -1.089123    -5.000000             0
#
# [5 rows x 93 columns]

# %%
# Filter out the first 85 days
train_data = train_data[train_data['date_id'] >= 85]

# Drop rows that are completely empty
train_data = train_data.dropna(how='all')

# %%
# Define columns to exclude
exclude_columns = ['date_id', 'time_id', 'symbol_id', 'weight', 'partition_id'] + \
                  [col for col in train_data.columns if col.startswith('responder_')]

# Select numerical columns
numerical_columns = [col for col in train_data.columns if col not in exclude_columns]

# %%
# Interpolate missing values for numerical columns
train_data[numerical_columns] = train_data[numerical_columns].interpolate(method='linear', axis=0)

# Drop rows with any remaining NaN values
train_data = train_data.dropna()

# %%
# Calculate IQR thresholds
q1 = train_data[numerical_columns].quantile(0.25)
q3 = train_data[numerical_columns].quantile(0.75)
iqr = q3 - q1

# Calculate lower and upper bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Clip outliers to bounds
train_data[numerical_columns] = train_data[numerical_columns].clip(lower=lower_bound, upper=upper_bound, axis=1)

# %%
# Initialize scaler
scaler = MinMaxScaler()

# Scale numerical columns
train_data[numerical_columns] = scaler.fit_transform(train_data[numerical_columns])

# %%
print(train_data[numerical_columns].head())
# Out:
#          feature_00  feature_01  feature_02  feature_03  feature_04  \
# 8212377    0.505810    0.724187    0.399453    0.454499    0.641736
# 8212378    0.418131    0.665448    0.426027    0.419061    0.495121
# 8212379    0.383212    0.825243    0.409935    0.398409    0.469392
# 8212380    0.479958    0.756942    0.353602    0.399388    0.480056
# 8212381    0.338658    0.795772    0.350866    0.393804    0.513743
#
#          feature_05  feature_06  feature_07  feature_08  feature_09  ...  \
# 8212377    0.488392         0.0    0.226021    0.449224      0.1125  ...
# 8212378    0.484060         0.0    0.099103    0.432922      0.9875  ...
# 8212379    0.495072         0.0    0.225261    0.448839      0.0250  ...
# 8212380    0.485809         0.0    0.065998    0.436263      0.0000  ...
# 8212381    0.485138         0.0    0.226461    0.459308      0.1125  ...
#
#          feature_69  feature_70  feature_71  feature_72  feature_73  \
# 8212377    0.625125    0.120495    1.000000    0.415631    0.395265
# 8212378    0.432357    0.181711    1.000000    0.453826    0.395290
# 8212379    0.273867    0.098508    0.378914    0.203118    0.395316
# 8212380    0.426533    0.208193    1.000000    0.434700    0.395341
# 8212381    0.321029    0.237788    0.268790    0.271148    0.395366
#
#          feature_74  feature_75  feature_76  feature_77  feature_78
# 8212377    0.496215    0.399476    0.403850    0.286898    0.315596
# 8212378    0.496004    1.000000    1.000000    0.432245    0.345661
# 8212379    0.495793    0.863386    0.986736    0.000000    0.063953
# 8212380    0.495582    0.417808    0.477923    0.368003    0.427206
# 8212381    0.495372    0.414351    0.463417    0.330104    0.408562
#
# [5 rows x 79 columns]

# %%
for col in numerical_columns:
    length = train_data[col].size  # Size of the column
    nan_count = train_data[col].isna().sum()  # Count of NaN values
    print(f"Column: {col}, Length: {length}, NaN Count: {nan_count}")
# Out:
# Column: feature_00, Length: 38914961, NaN Count: 0
# Column: feature_01, Length: 38914961, NaN Count: 0
# Column: feature_02, Length: 38914961, NaN Count: 0
# Column: feature_03, Length: 38914961, NaN Count: 0
# Column: feature_04, Length: 38914961, NaN Count: 0
# Column: feature_05, Length: 38914961, NaN Count: 0
# Column: feature_06, Length: 38914961, NaN Count: 0
# Column: feature_07, Length: 38914961, NaN Count: 0
# Column: feature_08, Length: 38914961, NaN Count: 0
# Column: feature_09, Length: 38914961, NaN Count: 0
# Column: feature_10, Length: 38914961, NaN Count: 0
# Column: feature_11, Length: 38914961, NaN Count: 0
# Column: feature_12, Length: 38914961, NaN Count: 0
# Column: feature_13, Length: 38914961, NaN Count: 0
# Column: feature_14, Length: 38914961, NaN Count: 0
# Column: feature_15, Length: 38914961, NaN Count: 0
# Column: feature_16, Length: 38914961, NaN Count: 0
# Column: feature_17, Length: 38914961, NaN Count: 0
# Column: feature_18, Length: 38914961, NaN Count: 0
# Column: feature_19, Length: 38914961, NaN Count: 0
# Column: feature_20, Length: 38914961, NaN Count: 0
# Column: feature_21, Length: 38914961, NaN Count: 0
# Column: feature_22, Length: 38914961, NaN Count: 0
# Column: feature_23, Length: 38914961, NaN Count: 0
# Column: feature_24, Length: 38914961, NaN Count: 0
# Column: feature_25, Length: 38914961, NaN Count: 0
# Column: feature_26, Length: 38914961, NaN Count: 0
# Column: feature_27, Length: 38914961, NaN Count: 0
# Column: feature_28, Length: 38914961, NaN Count: 0
# Column: feature_29, Length: 38914961, NaN Count: 0
# Column: feature_30, Length: 38914961, NaN Count: 0
# Column: feature_31, Length: 38914961, NaN Count: 0
# Column: feature_32, Length: 38914961, NaN Count: 0
# Column: feature_33, Length: 38914961, NaN Count: 0
# Column: feature_34, Length: 38914961, NaN Count: 0
# Column: feature_35, Length: 38914961, NaN Count: 0
# Column: feature_36, Length: 38914961, NaN Count: 0
# Column: feature_37, Length: 38914961, NaN Count: 0
# Column: feature_38, Length: 38914961, NaN Count: 0
# Column: feature_39, Length: 38914961, NaN Count: 0
# Column: feature_40, Length: 38914961, NaN Count: 0
# Column: feature_41, Length: 38914961, NaN Count: 0
# Column: feature_42, Length: 38914961, NaN Count: 0
# Column: feature_43, Length: 38914961, NaN Count: 0
# Column: feature_44, Length: 38914961, NaN Count: 0
# Column: feature_45, Length: 38914961, NaN Count: 0
# Column: feature_46, Length: 38914961, NaN Count: 0
# Column: feature_47, Length: 38914961, NaN Count: 0
# Column: feature_48, Length: 38914961, NaN Count: 0
# Column: feature_49, Length: 38914961, NaN Count: 0
# Column: feature_50, Length: 38914961, NaN Count: 0
# Column: feature_51, Length: 38914961, NaN Count: 0
# Column: feature_52, Length: 38914961, NaN Count: 0
# Column: feature_53, Length: 38914961, NaN Count: 0
# Column: feature_54, Length: 38914961, NaN Count: 0
# Column: feature_55, Length: 38914961, NaN Count: 0
# Column: feature_56, Length: 38914961, NaN Count: 0
# Column: feature_57, Length: 38914961, NaN Count: 0
# Column: feature_58, Length: 38914961, NaN Count: 0
# Column: feature_59, Length: 38914961, NaN Count: 0
# Column: feature_60, Length: 38914961, NaN Count: 0
# Column: feature_61, Length: 38914961, NaN Count: 0
# Column: feature_62, Length: 38914961, NaN Count: 0
# Column: feature_63, Length: 38914961, NaN Count: 0
# Column: feature_64, Length: 38914961, NaN Count: 0
# Column: feature_65, Length: 38914961, NaN Count: 0
# Column: feature_66, Length: 38914961, NaN Count: 0
# Column: feature_67, Length: 38914961, NaN Count: 0
# Column: feature_68, Length: 38914961, NaN Count: 0
# Column: feature_69, Length: 38914961, NaN Count: 0
# Column: feature_70, Length: 38914961, NaN Count: 0
# Column: feature_71, Length: 38914961, NaN Count: 0
# Column: feature_72, Length: 38914961, NaN Count: 0
# Column: feature_73, Length: 38914961, NaN Count: 0
# Column: feature_74, Length: 38914961, NaN Count: 0
# Column: feature_75, Length: 38914961, NaN Count: 0
# Column: feature_76, Length: 38914961, NaN Count: 0
# Column: feature_77, Length: 38914961, NaN Count: 0
# Column: feature_78, Length: 38914961, NaN Count: 0

# %%
# Check for columns with NaN values
nan_counts = train_data.isnull().sum()

# Filter columns with NaN values
columns_with_nan = nan_counts[nan_counts > 0]
print("Columns with NaN values:\n", columns_with_nan)

# %%
# Identify constant columns (zero variance)
constant_columns = [col for col in numerical_columns if train_data[col].nunique() == 1]
print("Constant columns:", constant_columns)

# Drop constant columns
train_data = train_data.drop(columns=constant_columns)
numerical_columns = [col for col in numerical_columns if col not in constant_columns]

# %%
# Calculate correlation matrix
corr_matrix = train_data[numerical_columns].corr().abs()

# Find highly correlated pairs
correlated_pairs = [(i, j) for i in corr_matrix.columns for j in corr_matrix.columns 
                    if i != j and corr_matrix.loc[i, j] > 0.9]

print("Highly correlated pairs:", correlated_pairs)

# %%
# Drop one column from each correlated pair
columns_to_drop = set()
for i, j in correlated_pairs:
    if i not in columns_to_drop and j not in columns_to_drop:
        columns_to_drop.add(j)

train_data = train_data.drop(columns=list(columns_to_drop))
numerical_columns = [col for col in numerical_columns if col not in columns_to_drop]
